# %%
d1 = {
  "name": "Jake",
  "age": 20
}

print(d1)
# Out:
# {'name': 'Jake', 'age': 20}

# %%
d2 = dict(a = 123, b = "HEllo", c = 3.14)

print(d2)
# Out:
# {'a': 123, 'b': 'HEllo', 'c': 3.14}

# %%
d1['age'] = 20

# %%
d1
# Out:
# {'name': 'Jake', 'age': 20}

# %%
for key in d1:
  print(key)
# Out:
# name
# age

# %%
for val in d1.values():
  print(val)
# Out:
# Jake
# 20

# %%
for name, val in d1.items():
  print(name, val)
# Out:
# name Jake
# age 20

# %%
if d1.get('rah'):
  print('Present')
else:
  print('Not Present')
# Out:
# Not Present

# %%
list1 = ['a', 'b', 'c']
list2 = [1, 2, 3]

res_dict = {}

[res for res in zip(list1, list2)]
# Out:
# [('a', 1), ('b', 2), ('c', 3)]

# %%
dict(zip(list1, list2))
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
marks = {'Physics': 67, 'Maths': 87, 'History': 75}

math_marks = marks.pop('Maths')

math_marks
# Out:
# 87

# %%
marks
# Out:
# {'Physics': 67, 'History': 75}

# %%
d1 = {
  "name": "Jake",
  "age": 20
}

print(d1)
# Out:
# {'name': 'Jake', 'age': 20}

# %%
d1.pop('name')
# Out:
# 'Jake'

# %%
d1
# Out:
# {'age': 20}
