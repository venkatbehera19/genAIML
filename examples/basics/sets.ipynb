# %%
### sets are mutable, uniindexed, donot contain duplicated and ordered is not preserved

s = {1, 2, 3, 4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
1
# Out:
# 1

# %%
s = set('hello')
s
# Out:
# {'e', 'h', 'l', 'o'}

# %%
l = [1, 2, 3, 1, 7]
non_duplicate = set(l)
non_duplicate
# Out:
# {1, 2, 3, 7}

# %%
d = {"GFG": 1, "for": 2, "Geeks": 3}
print(set(d))
# Out:
# {'GFG', 'Geeks', 'for'}

# %%
t = ("GFG", "for", "Geeks")
print(set(t))
# Out:
# {'GFG', 'Geeks', 'for'}

# %%
s = {3, 1, 4, 1, 5, 9, 2}

print(s)
# Out:
# {1, 2, 3, 4, 5, 9}

# %%
print(s[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(s[0])
#
# TypeError: 'set' object is not subscriptable
