# %%
## tuples are immutable ordered collection of elements
# we can not chnage after creation

tup = ()
print(tup)
# Out:
# ()

# %%
tup = ("venkat", "raman")
tup
# Out:
# ('venkat', 'raman')

# %%
li = [1, 2, 3 ,4, 5]
print(tuple(li))
# Out:
# (1, 2, 3, 4, 5)

# %%
tup = tuple('Geeks')
print(tup)
# Out:
# ('G', 'e', 'e', 'k', 's')

# %%
tup = ('welcome', 5, 'to', 1.76, True)
print(tup)

tup1 = (0, 1, 2, 3)
tup2 = ('python', 'geek')

tup3 = (tup1, tup2)

print(tup3)
# Out:
# ('welcome', 5, 'to', 1.76, True)
# ((0, 1, 2, 3), ('python', 'geek'))

# %%
tup1 = ('geeks', ) * 3
print(tup1)
# Out:
# ('geeks', 'geeks', 'geeks')

# %%
tup = tuple("Venkat")

print(tup)
print(tup[0])
print(tup[:])
print(tup[1:4])
print(tup[::-1])
print(tup[:3])
# Out:
# ('V', 'e', 'n', 'k', 'a', 't')
# V
# ('V', 'e', 'n', 'k', 'a', 't')
# ('e', 'n', 'k')
# ('t', 'a', 'k', 'n', 'e', 'V')
# ('V', 'e', 'n')

# %%
list1 = list(range(6))

# %%
list1[1::2]
# Out:
# [1, 3, 5]
