# %%
1 + 1
# Out:
# 2

# %%
# variables are dynamic type so there is no need of data declaration.

a = 120
b = 123.5
c = "Hello"

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 120
# 123.5
# Hello
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# dynamic typing
x = "Heelooo"
x = 2.4
x = ("geeks", "for", "geeks")

x
# Out:
# ('geeks', 'for', 'geeks')

# %%
# input always return string
val = input('Enter a number: ')
print("You entered: ", val)
print("You entered: ", type( val ))
# Out:
# You entered:  2
# You entered:  <class 'str'>

# %%
a = True
b = False

print(a and b)
print( a or b )
print( not a )
# Out:
# False
# True
# False

# %%
# if else

i = 10

if i == 10:
  print("Inside IF")
  print("IT IS 10")
elif i < 15:
  print("LESS THEN 15")
  print("Inside elif")
else:
  print("GRETER THEN 15")
  print("Inside Else")

print("i'm not in if and not in else Block")
# Out:
# Inside IF
# IT IS 10
# i'm not in if and not in else Block

# %%
# loops

for i in range(1, 10, 2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
count = 0
while(count < 3):
  print("COUNT", count)
  count = count + 1
# Out:
# COUNT 0
# COUNT 1
# COUNT 2

# %%
def odd_even(x):
  if x % 2 == 0:
    return "EVEN"
    # print("EVEN")
  else:
    print("ODD")
    return "ODD"

# %%
odd_even(x = 10)
# odd_even(3)
# Out:
# 'EVEN'

# %%
print(odd_even(10))
# Out:
# EVEN
