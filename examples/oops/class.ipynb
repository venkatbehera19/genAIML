# %%
### class is a collection of objects, it defines set of attributes and methods that created object can have.

# %%
class Dog:
  species = "Canine"
  # class attribute

  # constructor
  def __init__(self, name, age):
    self.name = name #instance attribute
    self.age = age #instance attribute

# %%
dog1 = Dog('Buddy', 3)
dog1

# %%
print(dog1.name)
print(dog1.species)
# Out:
# Buddy
# Canine
