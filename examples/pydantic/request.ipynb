# %%
import requests

# %%
response = requests.get('http://127.0.0.1:8000/user')
print(response.status_code)
print('RESPONSE', response.text)
# Out:
# 200
# RESPONSE [{"id":1,"name":"olll","age":20,"email":"user2@example.com"},{"id":2,"name":"olll","age":20,"email":"user2@example.com"}]

# %%
response
# Out:
# <Response [200]>

# %%
payload = {
  "email": "user2@example.com",
  "age": 20,
  "name": "olll"
}
response = requests.post("http://127.0.0.1:8000/user", json=payload)
print(response.text)

print(response)
# Out:
# {"id":2,"name":"olll","age":20,"email":"user2@example.com"}
# <Response [201]>
