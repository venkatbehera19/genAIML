# %%
import logging

logger = logging.getLogger("fastapi_app")

# %%
logger.handlers
# Out:
# []

# %%
not logger.handlers
# Out:
# True

# %%
print(logging.INFO)
# Out:
# 20

# %%
logging.StreamHandler()
# Out:
# <StreamHandler stderr (NOTSET)>

# %%
os.getenv("DATABASE_URL", "sqlite:///./data/sql_app.db")
# Out:
# 'sqlite:///./data/sql_app.db'

# %%
import os
